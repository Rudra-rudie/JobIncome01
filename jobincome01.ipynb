# %%
from sklearn.cluster import KMeans
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("income.csv")
df.head()
# Out:
#     name  age  income
# 0  Nafis   30   42717
# 1   Tara   49   36753
# 2  Arman   26  114281
# 3  Hasib   44   91064
# 4   Tara   42   84188

# %%
plt.scatter(df['age'],df['income'])

# %%
km = KMeans(n_clusters=3)
km
# Out:
# KMeans(n_clusters=3)

# %%
y_predicted = km.fit_predict(df[['age','income']])
y_predicted
# Out:
# array([0, 0, 1, 1, 1, 2, 2, 1, 0, 0, 2, 2, 1, 1, 0, 0, 0, 2, 1, 0, 2, 1,
#        2, 2, 1, 1, 1, 0, 2, 2, 0, 2, 0, 1, 1, 1, 1, 2, 1, 1, 1, 1, 1, 2,
#        1, 0, 1, 2, 1, 2], dtype=int32)

# %%
df['cluster'] = y_predicted
df.head()
# Out:
#     name  age  income  cluster
# 0  Nafis   30   42717        0
# 1   Tara   49   36753        0
# 2  Arman   26  114281        1
# 3  Hasib   44   91064        1
# 4   Tara   42   84188        1

# %%
df1 = df[df.cluster==0]
df2 = df[df.cluster==1]
df3 = df[df.cluster==2]

plt.scatter(df1.age,df1['income'],color='green')
plt.scatter(df2 .age,df2['income'],color='red')
plt.scatter(df3.age,df3['income'],color='blue')

plt.xlabel('age')
plt.ylabel('income')
plt.legend()
# Out:
# C:\Users\Rudro\AppData\Local\Temp\ipykernel_8920\1871301966.py:11: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

# fit on 2D dataframe
scaler.fit(df[['income']])

# transform on 2D dataframe
df['income'] = scaler.transform(df[['income']])

scaler.fit(df[['age']])
df['age'] = scaler.transform(df[['age']])
df
# Out:
#      name       age    income  cluster    Income
# 0   Nafis  0.292683  0.223704        0  0.223704
# 1    Tara  0.756098  0.163603        0  0.163603
# 2   Arman  0.195122  0.944868        1  0.944868
# 3   Hasib  0.634146  0.710906        1  0.710906
# 4    Tara  0.585366  0.641615        1  0.641615
# 5   Robin  0.195122  0.259004        2  0.259004
# 6    Maya  0.487805  0.307455        2  0.307455
# 7   Kabir  0.926829  0.685269        1  0.685269
# 8    Nila  0.707317  0.121158        0  0.121158
# 9     Eva  0.243902  0.189834        0  0.189834
# 10  Jarin  0.780488  0.481488        2  0.481488
# 11  Jarin  0.829268  0.348288        2  0.348288
# 12  Imran  0.024390  0.825513        1  0.825513
# 13   Lina  0.000000  0.949654        1  0.949654
# 14  Robin  0.390244  0.074491        0  0.074491
# 15    Eva  0.487805  0.022492        0  0.022492
# 16  Aarav  0.853659  0.080043        0  0.080043
# 17  Jarin  0.097561  0.428089        2  0.428089
# 18   Maya  0.804878  0.597658        1  0.597658
# 19   Nila  0.512195  0.000000        0  0.000000
# 20  Aarav  0.902439  0.516748        2  0.516748
# 21  Aarav  0.658537  0.794183        1  0.794183
# 22  Jarin  0.073171  0.430669        2  0.430669
# 23   Sami  0.560976  0.263720        2  0.263720
# 24  Kabir  0.560976  0.873118        1  0.873118
# 25   Maya  0.170732  0.697594        1  0.697594
# 26  Rudra  0.292683  0.657950        1  0.657950
# 27   Nila  0.048780  0.001915        0  0.001915
# 28   Riya  0.829268  0.491182        2  0.491182
# 29  Nadia  0.878049  0.296350        2  0.296350
# 30    Omi  0.317073  0.111575        0  0.111575
# 31   Sami  0.390244  0.568495        2  0.568495
# 32   Riya  0.731707  0.071165        0  0.071165
# 33  Nafis  0.682927  0.655723        1  0.655723
# 34  Robin  0.170732  0.600379        1  0.600379
# 35   Riya  0.634146  0.797731        1  0.797731
# 36  Nadia  0.414634  0.859413        1  0.859413
# 37    Eva  0.536585  0.395701        2  0.395701
# 38    Eva  0.804878  0.969093        1  0.969093
# 39  Aarav  0.073171  1.000000        1  1.000000
# 40  Robin  0.682927  0.609005        1  0.609005
# 41   Nila  0.804878  0.653707        1  0.653707
# 42  Aarav  0.073171  0.760092        1  0.760092
# 43  Nafis  0.487805  0.476742        2  0.476742
# 44  Nafis  0.024390  0.622791        1  0.622791
# 45   Maya  0.512195  0.035351        0  0.035351
# 46  Nadia  0.341463  0.636455        1  0.636455
# 47   Sami  0.317073  0.509170        2  0.509170
# 48   Tara  1.000000  0.889221        1  0.889221
# 49   Sara  0.926829  0.327015        2  0.327015

# %%
from sklearn.cluster import KMeans

km = KMeans(n_clusters=3)

y_predicted = km.fit_predict(df[['age', 'income']])

y_predicted
# Out:
# array([2, 0, 1, 1, 1, 2, 2, 0, 0, 2, 0, 0, 1, 1, 2, 2, 0, 2, 0, 2, 0, 1,
#        2, 2, 1, 1, 1, 2, 0, 0, 2, 1, 0, 0, 1, 1, 1, 0, 1, 1, 0, 0, 1, 1,
#        1, 2, 1, 1, 0, 0], dtype=int32)

# %% [markdown]
# df['cluster'] = y_predicted
# df.drop('cluster', axis='columns', inplace=True)
# df

# %%
km.cluster_centers_
# Out:
# array([[0.80200861, 0.43431331],
#        [0.34268293, 0.74478808],
#        [0.32457786, 0.1806383 ]])

# %%
df['cluster'] = y_predicted

df1 = df[df.cluster==0]
df2 = df[df.cluster==1]
df3 = df[df.cluster==2]

plt.scatter(df1.age,df1['income'],color='green')
plt.scatter(df2 .age,df2['income'],color='red')
plt.scatter(df3.age,df3['income'],color='blue')

plt.xlabel('age')
plt.ylabel('income')
plt.legend()
# Out:
# C:\Users\Rudro\AppData\Local\Temp\ipykernel_8920\709957618.py:13: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
k_rng = range(1,10)
sse = []
for k in k_rng:
    km = KMeans(n_clusters=k)
    km.fit(df[['age','income']])
    sse.append(km.inertia_)

# %%
sse
# Out:
# [8.463974440189332,
#  5.315926543178331,
#  2.7361038350649,
#  2.3988494650258967,
#  1.7940323945263368,
#  1.4161312040554843,
#  1.1780833591285833,
#  1.03289833938633,
#  0.8125995671403694]

# %%
plt.xlabel('k')
plt.ylabel('Sum of squared error')
plt.plot(k_rng,sse)
